# %%
print("hello")
# Out:
# hello

# %%
print ("EDA START PANNA POROM")
# Out:
# EDA START PANNA POROM

# %%
import os

# %%
os.listdir("data")
# Out:
# ['processed', 'raw']

# %%
os.path.isdir("data")
# Out:
# True

# %%
os.path.join("data","raw","2023-10.yaml")
# Out:
# 'data\\raw\\2023-10.yaml'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\rajap\\OneDrive\\Documents\\Data-Driven stock-price-analysis'

# %%
RAW_DATA_DIR= "data/raw"

# %%
import os

# %%
for month_folder in os.listdir(RAW_DATA_DIR):
    month_path = os.path.join(RAW_DATA_DIR, month_folder)
